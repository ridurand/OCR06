# %% [markdown]
# # Initialisation du notebook
#
# L'objectif du module est de développer un système de suggestion de tags pour le site Stack Overflow. Celui-ci prendra la forme d’un algorithme de machine learning qui assigne automatiquement plusieurs tags pertinents à une question.
#
# Ce notebook se consacre à l'exploration des données brutes.

# %%
# %%javascript
# IPython.OutputArea.auto_scroll_threshold=10

# %%
# -*- coding: utf-8 -*-
# %matplotlib inline
import numpy as np
import pandas as pd
import pandas_profiling
import matplotlib.pyplot as plt
import seaborn as sns
import glob, os, pickle, warnings
import re
from sklearn.preprocessing import MultiLabelBinarizer
import collections

# Déclaration de variables 

data_path = r"C:\OCR\06 _ Catégorisez automatiquement des questions"
   
pd.options.mode.chained_assignment = None # default='warn'
pd.set_option('display.max_columns', None)  
pd.set_option('display.max_colwidth', -1)
pd.set_option('display.max_rows', None)
pd.options.display.float_format = '{:,.2f}'.format
warnings.filterwarnings("ignore")

# %% [markdown]
# # Chargement et découverte des données brutes

# %%
all_files = glob.glob(os.path.join(data_path, "QueryResults*.csv")) 

li = []

for absolute_filename in all_files:
    path, file = os.path.split(absolute_filename)
    df = pd.read_csv(absolute_filename, sep=',', encoding='utf-8', engine='python', error_bad_lines=False)
    li.append(df)

df_brut = pd.concat(li, axis=0, ignore_index=True)

print('Taille du CSV importé : {0}'.format(df_brut.shape))

print(pd.DataFrame(df_brut.dtypes, columns=['Type']))
# Out:
# Taille du CSV importé : (91947, 6)
#          Type
# Id     int64
# Name   object
# Score  int64
# Body   object
# Title  object
# Tags   object

# %%
df_brut.to_pickle("./df_brut.pkl")

# %% [markdown]
# Les données extraites ciblent uniquement les posts de type "Question" dont les Id sont compris entre 0 et 600000.

# %%
df_brut = pd.read_pickle('./df_brut.pkl')

# %% [markdown]
# # Pandas Profiling

# %%
profile = df_brut.profile_report(title='Pandas Profiling Report', style={'full_width':True})
profile.to_file(output_file="output.html")

# %% [markdown]
# Aucune valeur manquante dans BODY, TITLE et TAGS

# %%
import matplotlib.pyplot as plt

# Boxplot of the variable Score
plt.figure(figsize=(5, 5))
plt.title("Boxplot of Score", fontsize=20)

# Boxplot without showing the outliers 
plt.xticks(size=15)
plt.yticks(size=15)
plt.boxplot(df_brut["Score"], showfliers=False, labels=['Score'])
plt.style.use('fivethirtyeight')
plt.show()

# %%
posts_tags = df_brut[df_brut.Score >= 3]['Tags']
posts_body = df_brut[df_brut.Score >= 3]['Body']
print("Nombre de posts :", posts_tags.shape[0])
# Out:
# Nombre de posts : 55598

# %% [markdown]
# # Analyse de la variable TAGS

# %%
posts_tags.head(5)
# Out:
# 0    <c#><floating-point><type-conversion><double><decimal>
# 1    <html><css><internet-explorer-7>
# 2    <c#><.net><datetime>
# 3    <c#><datetime><time><datediff><relative-time-span>
# 4    <html><browser><timezone><user-agent><timezone-offset>
# Name: Tags, dtype: object

# %%
# création d'un ensemble contenant tous les tags à partir des données du dataframe
# l'avantage d'un ensemble, c'est qu'un élément ne peut s'y trouver que 0 ou 1 fois 

set_tags = set() 

for list_keywords in (posts_tags.str.split('>').values):       
    # je rétablis le séparateur utilisé pour séparer les tags    
    list_keywords.remove('')
    list_keywords = [keyword+'>' for keyword in list_keywords] 
    set_tags = set_tags.union(list_keywords)

print('There are %d tags' % len(set_tags))
# Out:
# There are 9712 tags

# %%
posts_tags.loc[posts_tags.str.contains('<d>')].head(10)
# Out:
# 5145     <d>
# 9336     <memory><memory-management><d><garbage-collection>
# 15091    <multithreading><performance><d><thread-local-storage>
# 18400    <c><performance><d><standard-library>
# 20945    <.net><interop><d>
# 24157    <arrays><d><dmd>
# 28225    <performance><multithreading><optimization><parallel-processing><d>
# 32839    <d><popularity>
# 36866    <editor><d>
# 37683    <input><d><tango>
# Name: Tags, dtype: object

# %%
# je compte les occurrences de chaque tag dans le dataframe
alltags_count = dict()
for s in set_tags: 
    #print(s)
    alltags_count[s] = posts_tags.str.count(re.escape(s)).sum()

# %%
alltags_count = sorted(alltags_count.items(), key=lambda x: x[1], reverse=True)

# %%
import matplotlib.pyplot as plt
# Graphique des 30 tags les plus utilisés sur Stackoverflow

top30tags = alltags_count[1:31]

plt.figure(figsize=(20, 5))
y_axis = [i[1] for i in top30tags]
label_x = [i[0] for i in top30tags]
ax = plt.axes()
plt.bar(label_x, y_axis)
plt.xticks(rotation=90, fontsize=15)
plt.yticks(fontsize=15)
plt.title("30 most used tags on Stackoverflow",fontsize=20)
plt.xlabel('Tag', fontsize=18)
plt.ylabel('Number of occurrences', fontsize=18)
plt.style.use('fivethirtyeight')
plt.show()

# %% [markdown]
# ### Nombre de posts impactés par les 100 à 1000 premiers tags

# %%
nb_posts_targeted = dict() 

for nb_top_tags in np.linspace(100, 1000, 10, dtype='int'):

    top_tags = [i[0] for i in alltags_count[1:nb_top_tags+1]]
    nb_posts_targeted[nb_top_tags] = 0
    
    for _tags in posts_tags.str.split('>'):
        _tags.remove('')
        _tags = [_tag[1:] for _tag in _tags] 
        for _tag in _tags:
            if _tag in top_tags:
                nb_posts_targeted[nb_top_tags] += 1
                break

    percentage_posts = (nb_posts_targeted[nb_top_tags]/posts_tags.shape[0])*100
    print('With %d tags kept, %.2f %% of the posts are concerned ' % (nb_top_tags, percentage_posts))
# Out:
# With 100 tags kept, 0.00 % of the posts are concerned
# With 200 tags kept, 0.00 % of the posts are concerned
# With 300 tags kept, 0.00 % of the posts are concerned
# With 400 tags kept, 0.00 % of the posts are concerned
# With 500 tags kept, 0.00 % of the posts are concerned
# With 600 tags kept, 0.00 % of the posts are concerned
# With 700 tags kept, 0.00 % of the posts are concerned
# With 800 tags kept, 0.00 % of the posts are concerned
# With 900 tags kept, 0.00 % of the posts are concerned
# With 1000 tags kept, 0.00 % of the posts are concerned

# %%
nb_posts_targeted = dict() 

for nb_top_tags in np.linspace(100, 1000, 10, dtype='int'):

    top_tags = [i[0] for i in alltags_count[1:nb_top_tags+1]]
    nb_posts_targeted[nb_top_tags] = 0
    
    for tags in top_tags:
        nb_posts_targeted[nb_top_tags] += posts_tags.str.count(re.escape(tags)).sum()         

    percentage_posts = (nb_posts_targeted[nb_top_tags]/posts_tags.shape[0])*100
    print('With %d tags kept, %.2f %% of the posts are concerned ' % (nb_top_tags, percentage_posts))
# Out:
# With 100 tags kept, 133.58 % of the posts are concerned
# With 200 tags kept, 164.57 % of the posts are concerned
# With 300 tags kept, 182.72 % of the posts are concerned
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-9573990c55dd> in <module>
#       7
#       8     for tags in top_tags:
# ----> 9         nb_posts_targeted[nb_top_tags] += posts_tags.str.count(re.escape(tags)).sum()
#      10
#      11     percentage_posts = (nb_posts_targeted[nb_top_tags]/posts_tags.shape[0])*100
#
# ~\Anaconda3\lib\site-packages\pandas\core\strings.py in wrapper(self, *args, **kwargs)
#    1841                 )
#    1842                 raise TypeError(msg)
# -> 1843             return func(self, *args, **kwargs)
#    1844
#    1845         wrapper.__name__ = func_name
#
# ~\Anaconda3\lib\site-packages\pandas\core\strings.py in wrapper2(self, pat, flags, **kwargs)
#    1874     @forbid_nonstring_types(forbidden_types, name=name)
#    1875     def wrapper2(self, pat, flags=0, **kwargs):
# -> 1876         result = f(self._parent, pat, flags=flags, **kwargs)
#    1877         return self._wrap_result(result)
#    1878
#
# ~\Anaconda3\lib\site-packages\pandas\core\strings.py in str_count(arr, pat, flags)
#     212     regex = re.compile(pat, flags=flags)
#     213     f = lambda x: len(regex.findall(x))
# --> 214     return _na_map(f, arr, dtype=int)
#     215
#     216
#
# ~\Anaconda3\lib\site-packages\pandas\core\strings.py in _na_map(f, arr, na_result, dtype)
#     103 def _na_map(f, arr, na_result=np.nan, dtype=object):
#     104     # should really _check_ for NA
# --> 105     return _map(f, arr, na_mask=True, na_value=na_result, dtype=dtype)
#     106
#     107
#
# ~\Anaconda3\lib\site-packages\pandas\core\strings.py in _map(f, arr, na_mask, na_value, dtype)
#     118         try:
#     119             convert = not all(mask)
# --> 120             result = lib.map_infer_mask(arr, f, mask.view(np.uint8), convert)
#     121         except (TypeError, AttributeError) as e:
#     122             # Reraise the exception if callable `f` got wrong number of args.
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer_mask()
#
# ~\Anaconda3\lib\site-packages\pandas\core\strings.py in <lambda>(x)
#     211     """
#     212     regex = re.compile(pat, flags=flags)
# --> 213     f = lambda x: len(regex.findall(x))
#     214     return _na_map(f, arr, dtype=int)
#     215
#
# KeyboardInterrupt:

# %%
nb_posts_targeted = dict() 
  top_tags = [i[0] for i in alltags_count[1:nb_top_tags+1]]
    nb_posts_targeted[nb_top_tags] = 0
    
    for tags in top_tags:
        nb_posts_targeted[nb_top_tags] += posts_tags.str.count(re.escape(tags)).sum()         

cnt = Counter()
for word in ['red', 'blue', 'red', 'green', 'blue', 'blue']:
...     cnt[word] += 1

# %%
# je compte les occurrences de chaque tag dans le dataframe
#for s in set_tags: 
    #print(s)
#    cnt[word] += 1
#    alltags_count[s] = posts_tags.str.count(re.escape(s)).sum() 
top_tags = [i[0] for i in alltags_count[1:101]]
print(c)
# Out:
# 0    [<c#, <floating-point, <type-conversion, <double, <decimal, ]
# 1    [<html, <css, <internet-explorer-7, ]
# 2    [<c#, <.net, <datetime, ]
# 3    [<c#, <datetime, <time, <datediff, <relative-time-span, ]
# 4    [<html, <browser, <timezone, <user-agent, <timezone-offset, ]
# 5    [<.net, <math, ]
# 6    [<c#, <linq, <web-services, <.net-3.5, ]
# 7    [<mysql, <database, <binary-data, <data-storage, ]
# 8    [<performance, <algorithm, <language-agnostic, <unix, <pi, ]
# 9    [<mysql, <database, <triggers, ]
# Name: Tags, dtype: object
# Counter({'': 55598, '<c#': 7703, '<.net': 5675, '<java': 4535, '<c++': 3297, '<asp.net': 2694, '<python': 2616, '<javascript': 2595, '<php': 2015, '<sql': 1902, '<sql-server': 1728, '<windows': 1419, '<c': 1360, '<html': 1351, '<visual-studio': 1113, '<database': 1106, '<jquery': 1060, '<mysql': 1054, '<ruby': 974, '<css': 965, '<asp.net-mvc': 946, '<performance': 943, '<wpf': 936, '<linux': 913, '<winforms': 854, '<xml': 849, '<ruby-on-rails': 823, '<svn': 793, '<iphone': 770, '<algorithm': 741, '<unit-testing': 739, '<language-agnostic': 718, '<regex': 656, '<vb.net': 654, '<multithreading': 651, '<perl': 644, '<visual-studio-2008': 643, '<string': 621, '<linq': 590, '<version-control': 586, '<security': 583, '<oop': 569, '<delphi': 566, '<user-interface': 552, '<eclipse': 550, '<debugging': 531, '<oracle': 523, '<objective-c': 516, '<macos': 493, '<winapi': 479, '<ajax': 477, '<web-services': 476, '<cocoa-touch': 471, '<sql-server-2005': 442, '<wcf': 442, '<design-patterns': 437, '<arrays': 425, '<django': 422, '<cocoa': 386, '<testing': 380, '<exception': 380, '<generics': 375, '<tsql': 375, '<linq-to-sql': 360, '<optimization': 357, '<file': 333, '<apache-flex': 324, '<git': 323, '<excel': 320, '<unix': 318, '<sharepoint': 317, '<http': 311, '<database-design': 311, '<parsing': 308, '<apache': 301, '<flash': 297, '<bash': 297, '<coding-style': 291, '<networking': 283, '<.net-3.5': 282, '<command-line': 275, '<shell': 270, '<nhibernate': 269, '<math': 268, '<reflection': 268, '<iis': 267, '<web-applications': 266, '<image': 264, '<silverlight': 255, '<deployment': 253, '<logging': 252, '<datetime': 251, '<scripting': 247, '<emacs': 247, '<internet-explorer': 246, '<memory': 244, '<architecture': 240, '<vim': 236, '<validation': 235, '<events': 235, '<email': 234, '<ide': 232, '<swing': 228, '<data-binding': 225, '<actionscript-3': 224, '<open-source': 223, '<caching': 222, '<stored-procedures': 220, '<.net-2.0': 220, '<hibernate': 218, '<authentication': 216, '<configuration': 216, '<browser': 214, '<list': 214, '<inheritance': 212, '<serialization': 212, '<stl': 212, '<data-structures': 209, '<compiler-construction': 206, '<vba': 206, '<visual-studio-2005': 202, '<unicode': 201, '<templates': 201, '<xslt': 200, '<firefox': 199, '<visual-c++': 198, '<memory-management': 198, '<postgresql': 197, '<dll': 195, '<xaml': 194, '<collections': 192, '<sockets': 191, '<json': 191, '<tdd': 189, '<ios': 188, '<orm': 188, '<date': 187, '<syntax': 186, '<gcc': 185, '<windows-vista': 184, '<ms-access': 183, '<forms': 180, '<pdf': 179, '<session': 178, '<class': 177, '<search': 176, '<url': 176, '<rest': 175, '<dom': 175, '<functional-programming': 173, '<refactoring': 173, '<batch-file': 171, '<frameworks': 170, '<model-view-controller': 169, '<tfs': 169, '<sorting': 168, '<function': 168, '<vb6': 166, '<file-io': 166, '<entity-framework': 166, '<api': 166, '<interface': 165, '<spring': 162, '<java-ee': 161, '<enums': 161, '<graphics': 161, '<project-management': 161, '<encryption': 158, '<build-process': 157, '<plugins': 156, '<sqlite': 156, '<powershell': 156, '<jsp': 155, '<process': 149, '<reporting-services': 148, '<types': 146, '<encoding': 146, '<cross-platform': 145, '<concurrency': 143, '<tomcat': 143, '<boost': 142, '<audio': 141, '<pointers': 140, '<editor': 139, '<random': 138, '<xcode': 137, '<hash': 136, '<msbuild': 135, '<lisp': 134, '<ssl': 134, '<64-bit': 133, '<com': 132, '<ado.net': 132, '<mfc': 132, '<embedded': 131, '<windows-services': 129, '<programming-languages': 127, '<filesystems': 126, '<f#': 126, '<garbage-collection': 125, '<internationalization': 124, '<maven-2': 124, '<exception-handling': 123, '<opengl': 123, '<installer': 123, '<mocking': 123, '<xpath': 123, '<lambda': 122, '<error-handling': 122, '<variables': 121, '<build-automation': 121, '<installation': 120, '<formatting': 120, '<user-controls': 119, '<cookies': 119, '<controls': 117, '<android': 117, '<windows-installer': 115, '<interop': 114, '<s ...

# %%
import matplotlib.pyplot as plt
# Graphique représentant le pourcentage de posts qui ont au moins un des top tags

plt.figure(figsize=(20, 5))
y_axis = [nb_posts_targeted[i]/posts_tags.shape[0]*100 for i in np.arange(100,1100, 100)]
label_x = [str(i) for i in np.arange(100,1100, 100)]
ax = plt.axes()
plt.bar(label_x, y_axis)
plt.xticks(rotation=90, fontsize=15)
plt.yticks(fontsize=15)
plt.title("Percentage of posts that have at least one of the top tags",fontsize=20)
plt.xlabel('Total number of tags kept', fontsize=18)
plt.ylabel('Percentage of posts', fontsize=18)
plt.style.use('fivethirtyeight')
plt.show()

# %% [markdown]
# ### Nombre de posts impactés par les 10 à 100 premiers tags

# %%
nb_posts_targeted = dict() 

for nb_top_tags in np.linspace(10, 100, 10, dtype='int'):

    top_tags = [i[0] for i in alltags_count[1:nb_top_tags+1]]
    nb_posts_targeted[nb_top_tags] = 0
    
    for _tags in posts_tags.str.split('>'):
        _tags.remove('')
        _tags = [_tag[1:] for _tag in _tags]        
        for _tag in _tags:
            if _tag in top_tags:
                nb_posts_targeted[nb_top_tags] += 1
                break

    percentage_posts = (nb_posts_targeted[nb_top_tags]/posts_tags.shape[0])*100
    print('With %d tags kept, %.2f %% of the posts are concerned ' % (nb_top_tags, percentage_posts))
# Out:
# With 10 tags kept, 0.00 % of the posts are concerned
# With 20 tags kept, 0.00 % of the posts are concerned
# With 30 tags kept, 0.00 % of the posts are concerned
# With 40 tags kept, 0.00 % of the posts are concerned
# With 50 tags kept, 0.00 % of the posts are concerned
# With 60 tags kept, 0.00 % of the posts are concerned
# With 70 tags kept, 0.00 % of the posts are concerned
# With 80 tags kept, 0.00 % of the posts are concerned
# With 90 tags kept, 0.00 % of the posts are concerned
# With 100 tags kept, 0.00 % of the posts are concerned

# %%
import matplotlib.pyplot as plt
# Graphique représentant le pourcentage de posts qui ont au moins un des top tags

plt.figure(figsize=(20, 5))
y_axis = [nb_posts_targeted[i]/posts_tags.shape[0]*100 for i in np.arange(10,100, 10)]
label_x = [str(i) for i in np.arange(10,100, 10)]
ax = plt.axes()
plt.bar(label_x, y_axis)
plt.xticks(rotation=90, fontsize=15)
plt.yticks(fontsize=15)
plt.title("Percentage of posts that have at least one of the top tags",fontsize=20)
plt.xlabel('Total number of tags kept', fontsize=18)
plt.ylabel('Percentage of posts', fontsize=18)
plt.style.use('fivethirtyeight')
plt.show()

# %%
def most_common_tags(tags, top_tags, n_tags):
    ''' keep only the tags that are part of the top most used tags on StackOverflow
        filtered tags are sorted by order of appearance in top_tags list

    tags: tags associated to post
    top_tags: most_commonn tags
    n_tags: number of tags by sample
    '''
    
    clean_tags = tags.split('>')
    clean_tags.remove('')
    clean_tags = [_tag[1:] for _tag in clean_tags]     
    tags_filtered = []
    
    for _tag in clean_tags:
        if _tag in top_tags: 
            index = top_tags.index(_tag)
            tags_filtered.insert(index,_tag)    
    
    tags_filtered = tags_filtered[:n_tags]
    
    return tags_filtered

# %% [markdown]
# Je ne vais conserver qu'un nombre réduit de tags, d'une part, parce que c'est plus facile de prédire le bon tag à partir d'un nombre réduit de mots ; d'autre part, parce que dans les 10 000 tags, certains sont extrêmement confidentiels et spécifiques
#
# ### Top 100 tags = 74% des posts impactés
# ### Aucune limitation sur le nombre de tags par post

# %%
top100tags = [i[0] for i in alltags_count[1:101]]

print("Nombre de posts avant : {0}".format(posts_tags.shape[0]))

posts_top100tags = posts_tags.copy()
posts_top100tags = posts_top100tags.apply(lambda x: most_common_tags(x, top100tags, 5))
posts_top100tags = posts_top100tags.apply(lambda x: x if len(x)>0 else None)
posts_top100tags.dropna(inplace=True)

print('Nombre de posts après : {0}'.format(posts_top100tags.shape[0]))
# Out:
# Nombre de posts avant : 55598
# Nombre de posts après : 0

# %% [markdown]
# #### Fréquence des tags conservés

# %%
toptags_count = [i[1] for i in alltags_count[1:101]]
toptags_count = pd.Series(toptags_count / sum(toptags_count) * 100, index=top100tags)
toptags_count.apply(lambda x: "{0:.2f}%".format(x))
# Out:
# <.net>                  7.64%
# <java>                  6.11%
# <c++>                   4.44%
# <asp.net>               3.63%
# <python>                3.52%
# <javascript>            3.49%
# <php>                   2.71%
# <sql>                   2.56%
# <sql-server>            2.33%
# <windows>               1.91%
# <c>                     1.83%
# <html>                  1.82%
# <visual-studio>         1.50%
# <database>              1.49%
# <jquery>                1.43%
# <mysql>                 1.42%
# <ruby>                  1.31%
# <css>                   1.30%
# <asp.net-mvc>           1.27%
# <performance>           1.27%
# <wpf>                   1.26%
# <linux>                 1.23%
# <winforms>              1.15%
# <xml>                   1.14%
# <ruby-on-rails>         1.11%
# <svn>                   1.07%
# <iphone>                1.04%
# <algorithm>             1.00%
# <unit-testing>          1.00%
# <language-agnostic>     0.97%
# <regex>                 0.88%
# <vb.net>                0.88%
# <multithreading>        0.88%
# <perl>                  0.87%
# <visual-studio-2008>    0.87%
# <string>                0.84%
# <linq>                  0.79%
# <version-control>       0.79%
# <security>              0.79%
# <oop>                   0.77%
# <delphi>                0.76%
# <user-interface>        0.74%
# <eclipse>               0.74%
# <debugging>             0.71%
# <oracle>                0.70%
# <objective-c>           0.69%
# <macos>                 0.66%
# <winapi>                0.64%
# <ajax>                  0.64%
# <web-services>          0.64%
# <cocoa-touch>           0.63%
# <sql-server-2005>       0.60%
# <wcf>                   0.60%
# <design-patterns>       0.59%
# <arrays>                0.57%
# <django>                0.57%
# <cocoa>                 0.52%
# <testing>               0.51%
# <exception>             0.51%
# <generics>              0.50%
# <tsql>                  0.50%
# <linq-to-sql>           0.48%
# <optimization>          0.48%
# <file>                  0.45%
# <apache-flex>           0.44%
# <git>                   0.43%
# <excel>                 0.43%
# <unix>                  0.43%
# <sharepoint>            0.43%
# <database-design>       0.42%
# <http>                  0.42%
# <parsing>               0.41%
# <apache>                0.41%
# <bash>                  0.40%
# <flash>                 0.40%
# <coding-style>          0.39%
# <networking>            0.38%
# <.net-3.5>              0.38%
# <command-line>          0.37%
# <shell>                 0.36%
# <nhibernate>            0.36%
# <reflection>            0.36%
# <math>                  0.36%
# <iis>                   0.36%
# <web-applications>      0.36%
#                  0.36%
# <silverlight>           0.34%
# <deployment>            0.34%
# <logging>               0.34%
# <datetime>              0.34%
# <scripting>             0.33%
# <emacs>                 0.33%
# <internet-explorer>     0.33%
# <memory>                0.33%
# <architecture>          0.32%
# <vim>                   0.32%
# <validation>            0.32%
# <events>                0.32%
# <email>                 0.32%
# <ide>                   0.31%
# dtype: object

# %% [markdown]
# #### Nombre de tags par post et fréquence

# %%
# Binarizing the tags for the supervised models
multilabel_binarizer = MultiLabelBinarizer()
Y = multilabel_binarizer.fit_transform(posts_top100tags)
Y_sum = np.sum(Y,axis=1)
print([*collections.Counter(Y_sum).values()])
print([*collections.Counter(Y_sum).keys()])
print(Y.shape)
# Out:
# []
# []
# (0, 0)

# %%
import matplotlib.pyplot as plt
# Nombre de tags par document
Y_n_tags = np.sum(multilabel_binarizer.fit_transform(posts_top100tags),axis=1)
# Fréquence du nombre de tags par document
multiLabel_counts = collections.Counter(Y_n_tags)
# clés 
# print([x[0] for x in multiLabel_counts.most_common()])
# valeurs 
# print([x[1] for x in multiLabel_counts.most_common()])
plt.figure(figsize=(15,5)) 
ax = sns.barplot([x[0] for x in multiLabel_counts.most_common()], [x[1] for x in multiLabel_counts.most_common()])
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.title("Questions having multiple tags",fontsize=20)
plt.xlabel('Number of tags', fontsize=18)
plt.ylabel('Number of posts', fontsize=18)
#adding the text labels
rects = ax.patches
labels = [x[1] for x in multiLabel_counts.most_common()] / np.sum([x[1] for x in multiLabel_counts.most_common()]) 
labels = ["{:0.1%}".format(x) for x in labels]
for rect, label in zip(rects, labels):
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width()/2, height + 5, label, ha='center', va='bottom', fontsize=15)
plt.style.use('fivethirtyeight')    
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-5469eeb13bd2> in <module>
#       9 # print([x[1] for x in multiLabel_counts.most_common()])
#      10 plt.figure(figsize=(15,5))
# ---> 11 ax = sns.barplot([x[0] for x in multiLabel_counts.most_common()], [x[1] for x in multiLabel_counts.most_common()])
#      12 plt.xticks(fontsize=15)
#      13 plt.yticks(fontsize=15)
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3147                           estimator, ci, n_boot, units,
#    3148                           orient, color, palette, saturation,
# -> 3149                           errcolor, errwidth, capsize, dodge)
#    3150
#    3151     if ax is None:
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge)
#    1606         self.establish_variables(x, y, hue, data, orient,
#    1607                                  order, hue_order, units)
# -> 1608         self.establish_colors(color, palette, saturation)
#    1609         self.estimate_statistic(estimator, ci, n_boot)
#    1610
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in establish_colors(self, color, palette, saturation)
#     313         # Determine the gray color to use for the lines framing the plot
#     314         light_vals = [colorsys.rgb_to_hls(*c)[1] for c in rgb_colors]
# --> 315         lum = min(light_vals) * .6
#     316         gray = mpl.colors.rgb2hex((lum, lum, lum))
#     317
#
# ValueError: min() arg is an empty sequence

# %% [markdown]
# ### Limitation à 3 tags par post

# %%
print("Nombre de posts avant : {0}".format(posts_tags.shape[0]))

posts_top100tags_3labels = posts_tags.copy()
posts_top100tags_3labels = posts_top100tags_3labels.apply(lambda x: most_common_tags(x, top100tags, 3))
posts_top100tags_3labels = posts_top100tags_3labels.apply(lambda x: x if len(x)>0 else None)
posts_top100tags_3labels.dropna(inplace=True)

print('Nombre de posts après : {0}'.format(posts_top100tags_3labels.shape[0]))

# %% [markdown]
# #### Fréquence des tags conservés

# %%
# je recompte les occurrences de chaque tag vu que j'en ai réduit le nombre
alltags_count_reduced = dict()
for s in top100tags: 
    alltags_count_reduced[s] = posts_top100tags_3labels.apply(lambda x: ','.join(map(str, x))).str.count(re.escape(s)).sum() 
alltags_count_reduced = sorted(alltags_count_reduced.items(), key=lambda x: x[1], reverse=True)    
toptags_count = [i[1] for i in alltags_count_reduced]
toptags_count = pd.Series(toptags_count / sum(toptags_count) * 100, index=top100tags)
toptags_count.apply(lambda x: "{0:.2f}%".format(x))

# %%
# Binarizing the tags for the supervised models
multilabel_binarizer = MultiLabelBinarizer()
Y = multilabel_binarizer.fit_transform(posts_top100tags_3labels)
Y_sum = np.sum(Y,axis=1)
print([*collections.Counter(Y_sum).values()])
print([*collections.Counter(Y_sum).keys()])
print(Y.shape)

# %%
import matplotlib.pyplot as plt
# Binarizing the tags for the supervised models
multilabel_binarizer = MultiLabelBinarizer()
# Nombre de tags par document
Y_n_tags = np.sum(multilabel_binarizer.fit_transform(posts_top100tags_3labels),axis=1)
# Fréquence du nombre de tags par document
multiLabel_counts = collections.Counter(Y_n_tags)
# clés 
# print([x[0] for x in multiLabel_counts.most_common()])
# valeurs 
# print([x[1] for x in multiLabel_counts.most_common()])
plt.figure(figsize=(15,5)) 
ax = sns.barplot([x[0] for x in multiLabel_counts.most_common()], [x[1] for x in multiLabel_counts.most_common()])
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.title("Questions having multiple tags",fontsize=20)
plt.xlabel('Number of tags', fontsize=18)
plt.ylabel('Number of posts', fontsize=18)
#adding the text labels
rects = ax.patches
labels = [x[1] for x in multiLabel_counts.most_common()] / np.sum([x[1] for x in multiLabel_counts.most_common()]) 
labels = ["{:0.1%}".format(x) for x in labels]
for rect, label in zip(rects, labels):
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width()/2, height + 5, label, ha='center', va='bottom', fontsize=15)
plt.style.use('fivethirtyeight')    
plt.show()

# %%
# SAUVEGARDE
top500tags = [i[0] for i in alltags_count[1:101]]
with open('top500tags.pkl', 'wb') as f:    
    pickle.dump(top500tags, f)
    
posts_body.to_pickle("./posts_body.pkl")
posts_top100tags.to_pickle("./posts_top100tags.pkl")
posts_top100tags_3labels.to_pickle("./posts_top100tags_3labels.pkl")
