# %% [markdown]
# # Initialisation du notebook
#
# L'objectif du module est de développer un système de suggestion de tag pour le site Stack Overflow. Celui-ci prendra la forme d’un algorithme de machine learning qui assigne automatiquement plusieurs tags pertinents à une question.
#
# Ce notebook se consacre à la modélisation supervisée et non supervisée de la recommandation de tags.

# %%
# %%javascript
# IPython.OutputArea.auto_scroll_threshold=10

# %%
# -*- coding: utf-8 -*-
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import glob, os, pickle, warnings
import re, spacy, nltk
from bs4 import BeautifulSoup
from nltk.corpus import stopwords
from string import punctuation

# no recognition of dependency labels and named entities 
nlp = spacy.load('en', disable=['parser', 'ner'])   
spacy_tokenizer = nlp.Defaults.create_tokenizer(nlp)

# Déclaration de variables 
data_path = r"C:\OCR\06 _ Catégorisez automatiquement des questions"
   
pd.options.mode.chained_assignment = None # default='warn'
pd.set_option('display.max_columns', None)  
pd.set_option('display.max_colwidth', -1)
pd.set_option('display.max_rows', None)
pd.options.display.float_format = '{:,.2f}'.format
warnings.filterwarnings("ignore")

# %%
# CHARGEMENT
with open('specialtags.pkl', 'rb') as f:
    specialtags = pickle.load(f) 

posts_topntags_3labels = pd.read_pickle("./posts_top100tags_3labels.pkl")
posts_body_clean = pd.read_pickle("./posts_body_clean.pkl")

# %% [markdown]
# # Préparation des données pour modélisation
#
# ### Scénario top 100 tags et 3 tags par post

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MultiLabelBinarizer

# %%
def model_preprocessing(tags, body):
    
    # Binarizing the tags for the supervised models
    mlb = MultiLabelBinarizer()
    Y_target = mlb.fit_transform(tags)
    
    # 80/20 split
    X_train, X_test, Y_train, Y_test = train_test_split(body, 
                                                        Y_target, 
                                                        test_size=0.2, train_size=0.8, random_state=42)
    
    tfidf = TfidfVectorizer(analyzer='word', 
                            encoding='utf-8', 
                            token_pattern=r'(?u)\S+', 
                            max_features=1000, min_df=0.0, max_df=0.95)
    
    # TF-IDF matrices
    # la littérature recommande de ne pas standardiser un TDIDF
    X_tfidf_train = tfidf.fit_transform(X_train)
    X_tfidf_test = tfidf.transform(X_test)

    return mlb, tfidf, X_tfidf_train, Y_train, X_test, X_tfidf_test, Y_test

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.multiclass import OneVsRestClassifier
from sklearn.pipeline import Pipeline

# Binarizing the tags for the supervised models
mlb = MultiLabelBinarizer()
Y_target = mlb.fit_transform(posts_topntags_3labels)
    
# 80/20 split
X_train, X_test, Y_train, Y_test = train_test_split(posts_body_clean, 
                                                    Y_target, 
                                                    test_size=0.2, train_size=0.8, random_state=42)

pipeline = Pipeline([
    ('tfidf', TfidfVectorizer(analyzer='word', encoding='utf-8', token_pattern=r'(?u)\S+')),
    ('clf', OneVsRestClassifier(LogisticRegression(solver='liblinear', penalty='l1', random_state=42)))])
     
parameters = {
    'tfidf__min_df': (0.0, 0.05),
    'tfidf__max_df': (0.95, 1.0),    
    'tfidf__max_features': (500, 1000), 
    'clf__estimator__C': (1, 10, 100)
}

grid_search_tune = GridSearchCV(pipeline, parameters, scoring='jaccard_weighted', n_jobs=2, verbose=3)
grid_search_tune.fit(X_train, Y_train)

print("Best parameters set:")
print(grid_search_tune.best_estimator_.steps)
print (grid_search_tune.best_params_, grid_search_tune.best_score_)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [Parallel(n_jobs=2)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done  28 tasks      | elapsed:  2.7min
# [Parallel(n_jobs=2)]: Done 120 out of 120 | elapsed: 30.8min finished
# Best parameters set:
# [('tfidf', TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#                 dtype=<class 'numpy.float64'>, encoding='utf-8',
#                 input='content', lowercase=True, max_df=0.95, max_features=1000,
#                 min_df=0.0, ngram_range=(1, 1), norm='l2', preprocessor=None,
#                 smooth_idf=True, stop_words=None, strip_accents=None,
#                 sublinear_tf=False, token_pattern='(?u)\\S+', tokenizer=None,
#                 use_idf=True, vocabulary=None)), ('clf', OneVsRestClassifier(estimator=LogisticRegression(C=10, class_weight=None,
#                                                  dual=False, fit_intercept=True,
#                                                  intercept_scaling=1,
#                                                  l1_ratio=None, max_iter=100,
#                                                  multi_class='auto',
#                                                  n_jobs=None, penalty='l1',
#                                                  random_state=42,
#                                                  solver='liblinear', tol=0.0001,
#                                                  verbose=0, warm_start=False),
#                     n_jobs=None))]
# {'clf__estimator__C': 10, 'tfidf__max_df': 0.95, 'tfidf__max_features': 1000, 'tfidf__min_df': 0.0} 0.331481985275994

# %%
mlb, tfidf, X_tfidf_train, Y_train, X_test, X_tfidf_test, Y_test = model_preprocessing(posts_topntags_3labels, posts_body_clean)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (38821,)
# (9706,)

# %%
# SAUVEGARDE
with open('tfidf.pkl', 'wb') as f:
    pickle.dump(tfidf, f)
with open('mlb.pkl', 'wb') as f:
    pickle.dump(mlb, f)

# %% [markdown]
# # Recommandation de tags
# ### Approche non supervisée

# %%
from sklearn.decomposition import LatentDirichletAllocation

# %%
def display_topics(model, feature_names, n_top_words):
    for topic_idx, topic in enumerate(model.components_):
        print("Topic %d:" % (topic_idx))
        print(" ".join([feature_names[i]
                        for i in topic.argsort()[:-n_top_words - 1:-1]]))

# %%
import matplotlib.pyplot as plt

best_perplexity = np.inf
best_lda = 0
perplexity_list = []
n_topics_list = []
lda_model_list = []

print("Extracting topics from LDA...")

# number of topics 
for n_topics in np.linspace(10, 20, 6, dtype='int'):
    lda_model = LatentDirichletAllocation(n_components=n_topics, max_iter=5, n_jobs=-1, random_state=42).fit(X_tfidf_train)
    n_topics_list.append(n_topics)
    perplexity = lda_model.perplexity(X_tfidf_test)
    perplexity_list.append(perplexity)
    lda_model_list.append(lda_model)

    # Perplexity is defined as exp(-1. * log-likelihood per word)
    # Perplexity: The smaller the better
    if perplexity <= best_perplexity:
        best_perplexity = perplexity
        best_lda = lda_model
# Out:
# Extracting topics from LDA...

# %%
from sklearn.model_selection import GridSearchCV

# Define Search Param
search_params = {'n_components': [10, 15, 20, 25, 30]}

# Init the Model
lda = LatentDirichletAllocation(n_jobs=-1, random_state=42)

# Init Grid Search Class
model_lda = GridSearchCV(lda, param_grid=search_params)

# Do the Grid Search
model_lda.fit(X_tfidf_train)
# Out:
# GridSearchCV(cv=None, error_score=nan,
#              estimator=LatentDirichletAllocation(batch_size=128,
#                                                  doc_topic_prior=None,
#                                                  evaluate_every=-1,
#                                                  learning_decay=0.7,
#                                                  learning_method='batch',
#                                                  learning_offset=10.0,
#                                                  max_doc_update_iter=100,
#                                                  max_iter=10,
#                                                  mean_change_tol=0.001,
#                                                  n_components=10, n_jobs=-1,
#                                                  perp_tol=0.1, random_state=42,
#                                                  topic_word_prior=None,
#                                                  total_samples=1000000.0,
#                                                  verbose=0),
#              iid='deprecated', n_jobs=None,
#              param_grid={'n_components': [10, 15, 20, 25, 30]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %%
model_lda.best_estimator_
# Out:
# LatentDirichletAllocation(batch_size=128, doc_topic_prior=None,
#                           evaluate_every=-1, learning_decay=0.7,
#                           learning_method='batch', learning_offset=10.0,
#                           max_doc_update_iter=100, max_iter=10,
#                           mean_change_tol=0.001, n_components=10, n_jobs=-1,
#                           perp_tol=0.1, random_state=42, topic_word_prior=None,
#                           total_samples=1000000.0, verbose=0)

# %%
class MyLDAWithPerplexityScorer(LatentDirichletAllocation):

    def score(self, X, y=None):

        # You can change the options passed to perplexity here
        score = super(MyLDAWithPerplexityScorer, self).perplexity(X, sub_sampling=False)

        # Since perplexity is lower for better, so we do negative
        return -1*score

lda_model = MyLDAWithPerplexityScorer(learning_method='online',   
                                      random_state=42,        
                                      n_jobs = -1)

search_params = {'n_components': [10, 20, 30]}
model_lda = GridSearchCV(lda_model, param_grid=search_params)
model_lda.fit(X_tfidf_train)
# Out:
# GridSearchCV(cv=None, error_score=nan,
#              estimator=MyLDAWithPerplexityScorer(batch_size=128,
#                                                  doc_topic_prior=None,
#                                                  evaluate_every=-1,
#                                                  learning_decay=0.7,
#                                                  learning_method='online',
#                                                  learning_offset=10.0,
#                                                  max_doc_update_iter=100,
#                                                  max_iter=10,
#                                                  mean_change_tol=0.001,
#                                                  n_components=10, n_jobs=-1,
#                                                  perp_tol=0.1, random_state=42,
#                                                  topic_word_prior=None,
#                                                  total_samples=1000000.0,
#                                                  verbose=0),
#              iid='deprecated', n_jobs=None,
#              param_grid={'n_components': [10, 20, 30]}, pre_dispatch='2*n_jobs',
#              refit=True, return_train_score=False, scoring=None, verbose=0)

# %%
#model_lda.best_estimator_
model_lda.cv_results_
# Out:
# {'mean_fit_time': array([41.09264574, 45.39781027, 46.27316771]),
#  'std_fit_time': array([0.91958322, 1.37139022, 1.33507017]),
#  'mean_score_time': array([0.79578362, 0.94231091, 0.78441753]),
#  'std_score_time': array([0.04354267, 0.30627964, 0.02705685]),
#  'param_n_components': masked_array(data=[10, 20, 30],
#               mask=[False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'n_components': 10}, {'n_components': 20}, {'n_components': 30}],
#  'split0_test_score': array([ -2885.07294687,  -6742.18620124, -11682.93428218]),
#  'split1_test_score': array([ -2853.46088862,  -7000.49808751, -13395.16072114]),
#  'split2_test_score': array([ -2815.43835381,  -6830.25590226, -13041.59038342]),
#  'split3_test_score': array([ -2812.63894329,  -6961.6022749 , -13254.13242759]),
#  'split4_test_score': array([ -2865.64021421,  -7070.25460059, -13345.19669837]),
#  'mean_test_score': array([ -2846.45026936,  -6920.9594133 , -12943.80290254]),
#  'std_test_score': array([ 28.33393252, 118.7049149 , 641.94973995]),
#  'rank_test_score': array([1, 2, 3])}

# %%
# Get Log Likelyhoods from Grid Search Output
n_topics = [10, 20, 30]
perplexity = model_lda.cv_results_['mean_test_score']

# Show graph
plt.figure(figsize=(12, 8))
plt.plot(n_topics, perplexity, label='0.5')
plt.title("Choosing Optimal LDA Model")
plt.xlabel("Num Topics")
plt.ylabel("Perplexity")
plt.show()

# %%
inv_specialtags = {v: k for k, v in dict(specialtags).items()}
words_label = []
for word in tfidf.get_feature_names():
    if word in inv_specialtags.keys():
        words_label.append(inv_specialtags[word])
    else:
        words_label.append(word)

plt.figure(figsize=(12,8))
first_topic = model_lda.best_estimator_.components_[0]
first_topic_words = [words_label[i] for i in first_topic.argsort()[:-50 - 1 :-1]]
firstcloud = WordCloud(background_color='black').generate(" ".join(first_topic_words))
plt.imshow(firstcloud, interpolation="bilinear")
plt.axis('off');

# %%
plt.figure(figsize=(8, 4))
plt.title("Evolution of perplexity score depending on number of topics",fontsize=16)
plt.xlabel("Number of topics", fontsize=14)
plt.ylabel("Perplexity", fontsize=14)
plt.xticks(fontsize=11)
plt.yticks(fontsize=11)
plt.plot(n_topics_list, perplexity_list)
plt.style.use('fivethirtyeight')
plt.show()

# %%
tfidf.get_feature_names()
# Out:
# ['ability',
#  'abstraction',
#  'access',
#  'account',
#  'action',
#  'activity',
#  'ad',
#  'add',
#  'addition',
#  'address',
#  'administrator',
#  'advance',
#  'advantage',
#  'advice',
#  'agent',
#  'ajax',
#  'alert',
#  'algorithm',
#  'allocation',
#  'alter',
#  'alternative',
#  'analysis',
#  'animation',
#  'annotation',
#  'apache',
#  'api',
#  'app',
#  'append',
#  'apple',
#  'application',
#  'architecture',
#  'area',
#  'array',
#  'arrays',
#  'article',
#  'asp',
#  'aspect',
#  'aspx',
#  'aspxyzspecialtags1zyx',
#  'assembly',
#  'assignment',
#  'assume',
#  'assumption',
#  'attachment',
#  'attack',
#  'attempt',
#  'attribute',
#  'authentication',
#  'author',
#  'auto',
#  'avoid',
#  'b',
#  'backend',
#  'background',
#  'backup',
#  'bar',
#  'base',
#  'bash',
#  'basis',
#  'batch',
#  'bean',
#  'behavior',
#  'behaviour',
#  'benefit',
#  'beta',
#  'binary',
#  'bind',
#  'binding',
#  'bit',
#  'block',
#  'blog',
#  'body',
#  'bonus',
#  'book',
#  'boost',
#  'border',
#  'box',
#  'bracket',
#  'branch',
#  'break',
#  'breakpoint',
#  'browser',
#  'buffer',
#  'bug',
#  'build',
#  'builder',
#  'building',
#  'bunch',
#  'bundle',
#  'business',
#  'button',
#  'byte',
#  'c',
#  'calculate',
#  'calculation',
#  'call',
#  'callback',
#  'candidate',
#  'capability',
#  'capture',
#  'car',
#  'card',
#  'care',
#  'cast',
#  'catch',
#  'category',
#  'cause',
#  'cell',
#  'center',
#  'certificate',
#  'chain',
#  'chance',
#  'char',
#  'character',
#  'chart',
#  'checkbox',
#  'checking',
#  'checkout',
#  'cheer',
#  'child',
#  'choice',
#  'choose',
#  'chrome',
#  'chunk',
#  'circle',
#  'circumstance',
#  'clarification',
#  'clarify',
#  'class',
#  'clause',
#  'click',
#  'client',
#  'clone',
#  'closing',
#  'clue',
#  'cluster',
#  'cocoa',
#  'code',
#  'codebase',
#  'collection',
#  'collision',
#  'color',
#  'column',
#  'com',
#  'combination',
#  'command',
#  'commit',
#  'communication',
#  'community',
#  'company',
#  'compare',
#  'comparison',
#  'compatibility',
#  'compilation',
#  'compile',
#  'compiler',
#  'completion',
#  'complexity',
#  'component',
#  'compression',
#  'computer',
#  'con',
#  'concept',
#  'concern',
#  'condition',
#  'config',
#  'configuration',
#  'configure',
#  'conflict',
#  'connect',
#  'connection',
#  'consideration',
#  'console',
#  'constant',
#  'constraint',
#  'construct',
#  'constructor',
#  'consumer',
#  'contact',
#  'contain',
#  'container',
#  'content',
#  'context',
#  'contract',
#  'control',
#  'controller',
#  'convention',
#  'conversion',
#  'convert',
#  'cookie',
#  'copy',
#  'copying',
#  'core',
#  'corner',
#  'cost',
#  'count',
#  'counter',
#  'country',
#  'couple',
#  'course',
#  'coverage',
#  'cpp',
#  'cpu',
#  'crash',
#  'create',
#  'creation',
#  'credential',
#  'credit',
#  'criterion',
#  'cross',
#  'css',
#  'csv',
#  'ctrl',
#  'culture',
#  'cursor',
#  'curve',
#  'customer',
#  'cycle',
#  'd',
#  'dal',
#  'data',
#  'database',
#  'datagridview',
#  'dataset',
#  'datasource',
#  'date',
#  'datetime',
#  'datum',
#  'day',
#  'deal',
#  'debug',
#  'debugger',
#  'debugging',
#  'decision',
#  'declaration',
#  'declare',
#  'define',
#  'definition',
#  'degree',
#  'delay',
#  'delegate',
#  'delphi',
#  'dependency',
#  'deployment',
#  'depth',
#  'description',
#  'design',
#  'designer',
#  'desktop',
#  'destination',
#  'destructor',
#  'detail',
#  'determine',
#  'device',
#  'dialog',
#  'diff',
#  'digit',
#  'dimension',
#  'direction',
#  'directive',
#  'directory',
#  'disadvantage',
#  'discussion',
#  'disk',
#  'display',
#  'distance',
#  'distribution',
#  'div',
#  'divs',
#  'django',
#  'dll',
#  'doc',
#  'document',
#  'documentation',
#  'dom',
#  'domain',
#  'download',
#  'dozen',
#  'drag',
#  'draw',
#  'drive',
#  'driver',
#  'drop',
#  'dropdown',
#  'dump',
#  'duplicate',
#  'eclipse',
#  'edge',
#  'editing',
#  'edition',
#  'editor',
#  'effect',
#  'effort',
#  'emacs',
#  'email',
#  'employee',
#  'enable',
#  'encoding',
#  'encryption',
#  'endpoint',
#  'engine',
#  'enterprise',
#  'entity',
#  'entry',
#  'enum',
#  'enumeration',
#  'environment',
#  'escape',
#  'event',
#  'events',
#  'excel',
#  'exception',
#  'exe',
#  'execution',
#  'exist',
#  'exit',
#  'expert',
#  'explanation',
#  'explorer',
#  'export',
#  'expression',
#  'extension',
#  'extract',
#  'fact',
#  'factor',
#  'factory',
#  'fail',
#  'failure',
#  'fashion',
#  'fault',
#  'feature',
#  'feed',
#  'feedback',
#  'fetch',
#  'field',
#  'figure',
#  'filename',
#  'filesystem',
#  'fill',
#  'filter',
#  'find',
#  'finding',
#  'finish',
#  'fire',
#  'fix',
#  'flag',
#  'flash',
#  'flow',
#  'focus',
#  'folder',
#  'folk',
#  'follow',
#  'font',
#  'foo',
#  'footer',
#  'force',
#  'form',
#  'format',
#  'formula',
#  'forum',
#  'frame',
#  'framework',
#  'friend',
#  'fun',
#  'function',
#  'functionality',
#  'future',
#  'g',
#  'gain',
#  'game',
#  'garbage',
#  'gcc',
#  'gem',
#  'generate',
#  'generation',
#  'generator',
#  'generics',
#  'getter',
#  'git',
#  'goal',
#  'graph',
#  'graphic',
#  'grid',
#  'gridview',
#  'group',
#  'guess',
#  'gui',
#  'guidance',
#  'guide',
#  'guideline',
#  'guy',
#  'h',
#  'hack',
#  'hand',
#  'handle',
#  'handler',
#  'handling',
#  'hardware',
#  'hash',
#  'head',
#  'header',
#  'heap',
#  'height',
#  'helper',
#  'hibernate',
#  'hierarchy',
#  'highlight',
#  'hint',
#  'history',
#  'home',
#  'hook',
#  'hope',
#  'host',
#  'hour',
#  'html',
#  'http',
#  'https',
#  'hundred',
#  'i',
#  'icon',
#  'ide',
#  'identifier',
#  'identity',
#  'idiom',
#  'ignore',
#  'iis',
#  'image',
#  'impact',
#  'implement',
#  'implication',
#  'import',
#  'improvement',
#  'increase',
#  'increment',
#  'index',
#  'info',
#  'inherit',
#  'inheritance',
#  'initialization',
#  'injection',
#  'input',
#  'insert',
#  'insight',
#  'install',
#  'installation',
#  'installer',
#  'instance',
#  'instruction',
#  'int',
#  'integer',
#  'integration',
#  'interaction',
#  'interest',
#  'interface',
#  'internet',
#  'interpreter',
#  'interval',
#  'invoke',
#  'ip',
#  'iphone',
#  'item',
#  'iteration',
#  'iterator',
#  'jar',
#  'java',
#  'javascript',
#  'job',
#  'join',
#  'jquery',
#  'junit',
#  'kernel',
#  'key',
#  'keyboard',
#  'keyword',
#  'kind',
#  'know',
#  'knowledge',
#  'label',
#  'lack',
#  'language',
#  'laptop',
#  'launch',
#  'layer',
#  'layout',
#  'lead',
#  'leak',
#  'leave',
#  'legacy',
#  'length',
#  'let',
#  'letter',
#  'level',
#  'lib',
#  'library',
#  'license',
#  'life',
#  'light',
#  'limit',
#  'limitation',
#  'link',
#  'linq',
#  'linux',
#  'list',
#  'listbox',
#  'listener',
#  'listview',
#  'load',
#  'loading',
#  'location',
#  'lock',
#  'log',
#  'log4net',
#  'logging',
#  'logic',
#  'look',
#  'loop',
#  'loss',
#  'love',
#  'luck',
#  'machine',
#  'mail',
#  'maintenance',
#  'manage',
#  'management',
#  'manager',
#  'manipulation',
#  'manner',
#  'map',
#  'mapping',
#  'margin',
#  'mark',
#  'master',
#  'match',
#  'math',
#  'matter',
#  'max',
#  'mb',
#  'mean',
#  'meaning',
#  'measure',
#  'mechanism',
#  'medium',
#  'member',
#  'membership',
#  'memory',
#  'mention',
#  'menu',
#  'merge',
#  'mess',
#  'migration',
#  'mind',
#  'minute',
#  'mistake',
#  'modal',
#  'mode',
#  'model',
#  'modification',
#  'modify',
#  'module',
#  'moment',
#  'money',
#  'monitor',
#  'month',
#  'mouse',
#  'movie',
#  'mvc',
#  'mysql',
#  'name',
#  'namespace',
#  'nature',
#  'network',
#  'nhibernate',
#  'node',
#  'notice',
#  'notification',
#  'null',
#  'object',
#  'offer',
#  'office',
#  'one',
#  'oop',
#  'operation',
#  'operator',
#  'opinion',
#  'optimization',
#  'option',
#  'oracle',
#  'order',
#  'org',
#  'orm',
#  'outlook',
#  'output',
#  'overkill',
#  'overload',
#  'override',
#  'owner',
#  'p',
#  'pack',
#  'package',
#  'packet',
#  'pain',
#  'pair',
#  'panel',
#  'paper',
#  'paragraph',
#  'param',
#  'parameter',
#  'parent',
#  'parse',
#  'parser',
#  'parsing',
#  'part',
#  'party',
#  'pass',
#  'password',
#  'paste',
#  'patch',
#  'path',
#  'pattern',
#  'pc',
#  'pdf',
#  'percentage',
#  'performance',
#  'period',
#  'perl',
#  'permission',
#  'persistence',
#  'person',
#  'phone',
#  'photo',
#  'php',
#  'pick',
#  'picture',
#  'piece',
#  'pipe',
#  'pitfall',
#  'pixel',
#  'plan',
#  'planning',
#  'platform',
#  'play',
#  'player',
#  'plug',
#  'plugin',
#  'pm',
#  'png',
#  'point',
#  'pointer',
#  'policy',
#  'pool',
#  'pop',
#  'populate',
#  'port',
#  'portion',
#  'position',
#  'possibility',
#  'post',
#  'postback',
#  'power',
#  'powershell',
#  'precision',
#  'preference',
#  'presentation',
#  'press',
#  'prevent',
#  'preview',
#  'price',
#  'principle',
#  'print',
#  'printer',
#  'priority',
#  'privilege',
#  'pro',
#  'procedure',
#  'process',
#  'processing',
#  'processor',
#  'produce',
#  'production',
#  'profile',
#  'profiler',
#  'program',
#  'programmer',
#  'programming',
#  'progress',
#  'project',
#  'property',
#  'protocol',
#  'prototype',
#  'provider',
#  'proxy',
#  'purpose',
#  'push',
#  'python',
#  'quality',
#  'query',
#  'queue',
#  'quote',
#  'r',
#  'radio',
#  'rail',
#  'ram',
#  'range',
#  'rate',
#  'read',
#  'reader',
#  'reading',
#  'recommend',
#  'recommendation',
#  'record',
#  'redirect',
#  'refactor',
#  'reference',
#  'reflection',
#  'refresh',
#  'regex',
#  'region',
#  'register',
#  'registry',
#  'relation',
#  'relationship',
#  'release',
#  'reload',
#  'remove',
#  'render',
#  'rendering',
#  'repeat',
#  'repeater',
#  'replace',
#  'replacement',
#  'reply',
#  'report',
#  'reporting',
#  'repository',
#  'representation',
#  'request',
#  'requirement',
#  'research',
#  'resolution',
#  'resolve',
#  'resource',
#  'response',
#  'rest',
#  'restriction',
#  'retrieve',
#  'review',
#  'revision',
#  'right',
#  'risk',
#  'role',
#  'roll',
#  'root',
#  'route',
#  'row',
#  'ruby',
#  'rule',
#  'running',
#  'runtime',
#  'sake',
#  'sale',
#  'sample',
#  'save',
#  'scale',
#  'scenario',
#  'schema',
#  'scheme',
#  'school',
#  'scope',
#  'score',
#  'scratch',
#  'screen',
#  'script',
#  'scripting',
#  'scroll',
#  'sdk',
#  'search',
#  'second',
#  'section',
#  'security',
#  'segment',
#  'select',
#  'selection',
#  'selector',
#  'self',
#  'sense',
#  'sequence',
#  'serialization',
#  'series',
#  'server',
#  'service',
#  'session',
#  'setter',
#  'setting',
#  'setup',
#  'shape',
#  'share',
#  'sharepoint',
#  'sheet',
#  'shell',
#  'shift',
#  'shop',
#  'shortcut',
#  'show',
#  'sign',
#  'signal',
#  'signature',
#  'silverlight',
#  'simplicity',
#  'simulator',
#  'singleton',
#  'site',
#  'situation',
#  'size',
#  'skill',
#  'snippet',
#  'soap',
#  'socket',
#  'software',
#  'solve',
#  'sort',
#  'sound',
#  'source',
#  'sp1',
#  'space',
#  'span',
#  'specification',
#  'specify',
#  'speed',
#  'split',
#  'spring',
#  'sql',
#  'sqlite',
#  'ssl',
#  'stack',
#  'stackoverflow',
#  'stage',
#  'standard',
#  'start',
#  'startup',
#  'state',
#  'statement',
#  'statistic',
#  'status',
#  'stdout',
#  'step',
#  'stop',
#  'storage',
#  'store',
#  'story',
#  'strategy',
#  'stream',
#  'string',
#  'struct',
#  'structure',
#  'student',
#  'studio',
#  'style',
#  'sub',
#  'subclass',
#  'subject',
#  'submit',
#  'subversion',
#  'success',
#  'suite',
#  'sum',
#  'summary',
#  'suppose',
#  'svn',
#  'swing',
#  'switch',
#  'symbol',
#  'sync',
#  'synchronization',
#  'syntax',
#  'system',
#  'tab',
#  'table',
#  'tag',
#  'talk',
#  'target',
#  'tdd',
#  'team',
#  'technique',
#  'technology',
#  'temp',
#  'template',
#  'term',
#  'test',
#  'testing',
#  'textbox',
#  'theme',
#  'theory',
#  'think',
#  'thinking',
#  'thought',
#  'thousand',
#  'thread',
#  'threading',
#  'throw',
#  'tier',
#  'time',
#  'timeout',
#  'timer',
#  'timestamp',
#  'tip',
#  'title',
#  'today',
#  'tomcat',
#  'ton',
#  'toolkit',
#  'topic',
#  'touch',
#  'trace',
#  'track',
#  'traffic',
#  'transaction',
#  'transfer',
#  'transform',
#  'transition',
#  'translation',
#  'tree',
#  'trick',
#  'trigger',
#  'trouble',
#  'trunk',
#  'try',
#  'turn',
#  'tutorial',
#  'txt',
#  'understand',
#  'understanding',
#  'unit',
#  'unix',
#  'upload',
#  'url',
#  'usage',
#  'usb',
#  'utility',
#  'validate',
#  'validation',
#  'validator',
#  'var',
#  'variable',
#  'variation',
#  'variety',
#  'vector',
#  'vendor',
#  'version',
#  'video',
#  'view',
#  'viewer',
#  'vim',
#  'volume',
#  'vote',
#  'vs2008',
#  'wait',
#  'war',
#  'warning',
#  'wcf',
#  'web',
#  'webform',
#  'webpage',
#  'webserver',
#  'webservice',
#  'website',
#  'week',
#  'weight',
#  'wheel',
#  'whitespace',
#  'widget',
#  'width',
#  'window',
#  'windows',
#  'winforms',
#  'wish',
#  'wonder',
#  'word',
#  'workaround',
#  'worker',
#  'workflow',
#  'working',
#  'world',
#  'worry',
#  'wpf',
#  'wrap',
#  'wrapper',
#  'write',
#  'writing',
#  'wrong',
#  'www',
#  'xml',
#  'xyzspecialtags0zyx',
#  'xyzspecialtags13zyx',
#  'xyzspecialtags1zyx',
#  'xyzspecialtags23zyx',
#  'xyzspecialtags2zyx',
#  'yield',
#  'zend',
#  'zip',
#  'zone']

# %%
inv_specialtags = {v: k for k, v in dict(specialtags).items()}
words_label = []
for word in tfidf.get_feature_names():
    if word in inv_specialtags.keys():
        words_label.append(inv_specialtags[word])
    else:
        words_label.append(word)

n_top_words = 10
display_topics(lda_model_list[4], words_label, n_top_words)

#à remplacer par 18. Get the top 15 keywords each topic de https://www.machinelearningplus.com/nlp/topic-modeling-python-sklearn-examples/
# + distribution documents par topic
# Out:
# Topic 0:
# service web exception application wcf request client test server code
# Topic 1:
# iphone view sharepoint icon title folder application letter pro con
# Topic 2:
# project svn repository source git version subversion server branch application
# Topic 3:
# connection session html server network template operator code client application
# Topic 4:
# class c++ function c object code compiler c# constructor pointer
# Topic 5:
# java domain list memory expression performance application c# space windows
# Topic 6:
# image ruby perl linq assembly version .net print c# rail
# Topic 7:
# thread application control hash algorithm game tree time textbox code
# Topic 8:
# property class object window interface wpf collection control member code
# Topic 9:
# test unit date testing time code day datetime month exception
# Topic 10:
# python eclipse language .net project application editor programming java windows
# Topic 11:
# xml css javascript php html style document browser child parent
# Topic 12:
# flash silverlight linux video windows height header integer application library
# Topic 13:
# directory script windows server application machine path oracle permission database
# Topic 14:
# table sql database column row query datum server mysql field
# Topic 15:
# form jquery http com javascript delphi tag html button validation
# Topic 16:
# event email ajax events control button address javascript application dialog
# Topic 17:
# string function character array memory code python program output list

# %%
def unsupervised(text, lda):
    document_tfidf = tfidf.transform(text)
    proba_topic_sachant_document = lda.transform(document_tfidf)
    inv_specialtags = {v: k for k, v in dict(specialtags).items()}
    words_label = []
    for word in tfidf.get_feature_names():
        if word in inv_specialtags.keys():
            words_label.append(inv_specialtags[word])
        else:
            words_label.append(word)
    proba_word_sachant_topic = lda.components_ / lda.components_.sum(axis=1)[:, np.newaxis] # normalization    
    #print(proba_topic_sachant_document.shape)    
    #print(proba_word_sachant_topic.shape)    
    
    # proba_topic_sachant_document est de dimension d x t
    # proba_word_sachant_topic est de dimension t x w
    # je peux donc opérer un produit matriciel entre les 2 matrices pour calculer pour chaque document : proba(wordn)
    # j'obtiendrai une matrice proba_word_sachant_document de dimension d x w
    # il ne me restera plus qu'à choisir les "n_words" mots les plus probables
    proba_word_sachant_document = proba_topic_sachant_document.dot(proba_word_sachant_topic)  
    
    # je transforme la matrice en dataframe : 
    # data = les proba des mots pour chaque document
    # index = l'index des données en entrée
    # columns = les labels des mots sélectionnés en sortie du LDA
    df_wd = pd.DataFrame(data=proba_word_sachant_document,
                         index=text.index,
                         columns=words_label) 
    
    values = df_wd.columns.values[np.argsort(-df_wd.values, axis=1)[:, :5]]
    values = [", ".join(item) for item in values.astype(str)]
    #pred_unsupervised = pd.DataFrame(df_wd.columns.values[np.argsort(-df_wd.values, axis=1)[:, :n_words]],
    #                                 index=df_wd.index,
    #                                 columns = ['word' + str(i + 1) for i in range(n_words)])
    pred_unsupervised = pd.DataFrame(values,
                                     index=df_wd.index,
                                     columns = ['Unsupervised'])
    
    return pred_unsupervised

pd.concat([unsupervised(X_test[500:510], model_lda.best_estimator_), posts_body_clean.loc[X_test[500:510].index]], axis=1)
# Out:
#                                        Unsupervised  \
# 81429  image, test, php, css, html
# 86193  string, python, image, test, javascript
# 66678  table, sql, database, column, query
# 88366  class, function, object, c++, code
# 12671  image, test, css, unit, html
# 79622  server, sql, table, application, database
# 52174  javascript, application, form, code, control
# 58499  javascript, form, jquery, table, control
# 32823  application, server, windows, web, project
# 35898  table, sql, database, column, query
#
#                                                                                                                                                                     Body
# 81429  php function feed spit status
# 86193  css class form jquery selector
# 66678  database transaction command start datum transaction system web service datum block exception data structure language transaction database link behavior database
# 88366  override overload advantage name function
# 12671  collection readonlycollection code iterate collection interface readonlycollection collection interface reasoning
# 79622  web setup administer database installation sql server time installation door leak setting sql server caliber resource setup sql server
# 52174  stackoverflow site jquery jquery
# 58499  procedure html javascript mind abuse separation concern
# 32823  store permission repository party program repository blog state subversion store permission patch hook script url subversion store permission subversion
# 35898  studio create procedure iron speed designer

# %%
# SAUVEGARDE
with open('lda_model_list.pkl', 'wb') as f:
    pickle.dump(lda_model_list, f)

# %%
#import pyLDAvis.sklearn 
#pyLDAvis.enable_notebook()
#panel = pyLDAvis.sklearn.prepare(best_lda, X_tfidf_test_topntags, tfidf_topntags, mds='tsne')
#panel

# %% [markdown]
# ### Approche supervisée

# %%
import collections
# Fréquence du nombre de tags par document
Y_train_count = collections.Counter(np.sum(Y_train, axis=1))
Y_train_freq = [x[1]/sum(Y_train_count.values()) for x in Y_train_count.most_common()]
print(Y_train_count)
print(Y_train_freq)
Y_test_count = collections.Counter(np.sum(Y_test, axis=1))
Y_test_freq = [-x[1]/sum(Y_test_count.values()) for x in Y_test_count.most_common()]
diff = [x + y for x, y in zip(Y_train_freq, Y_test_freq)]
print(Y_test_count)
print(Y_test_freq)
labels = [x[0] for x in Y_train_count.most_common()]
print(diff)
# Out:
# Counter({1: 18996, 2: 14191, 3: 5634})
# [0.48932278921202443, 0.3655495736843461, 0.14512763710362947]
# Counter({1: 4724, 2: 3527, 3: 1455})
# [-0.48670925200906656, -0.3633834741397074, -0.14990727385122604]
# [0.002613537202957872, 0.0021660995446387, -0.004779636747596572]

# %%
plt.style.use('fivethirtyeight')
fig, ax = plt.subplots(figsize=(10,4))
train_barh = ax.barh(np.arange(len(Y_train_freq)), Y_train_freq, 0.9, label="Train Set", linewidth=0, align='center')
test_barh = ax.barh(np.arange(len(Y_test_freq)), Y_test_freq, 0.9, label="Test Set", linewidth=0, align='center')
diff_line, = ax.plot(diff, np.arange(len(Y_test_freq)),'y',linewidth=4, c='white')
ax.set_title("Répartition du nombre de tags par document dans les 2 datasets", fontsize=20)
plt.yticks(np.arange(len(labels)), labels, fontsize=15)
plt.ylim(-1,3)
for tick in ax.xaxis.get_major_ticks():
    tick.label.set_fontsize(15) 
ax.set_xlabel("Fréquence", fontsize=15)
ax.legend((train_barh[0],test_barh[0], diff_line),('Train Set','Test Set','Difference'), fontsize=15)
plt.show()

# %%
from collections import Counter
# Fréquence du nombre de tags par document
Y_train_count = Counter(x for y in mlb.inverse_transform(Y_train) for x in y)
Y_train_freq = [x[1]/sum(x[1] for x in Y_train_count.most_common(20)) for x in Y_train_count.most_common(20)]
print(Y_train_freq)
Y_test_count = Counter(x for y in mlb.inverse_transform(Y_test) for x in y)
Y_test_freq = [-x[1]/sum(x[1] for x in Y_test_count.most_common(20)) for x in Y_test_count.most_common(20)]
print(Y_test_freq)
diff = [x + y for x, y in zip(Y_train_freq, Y_test_freq)]
labels = [x[0] for x in Y_train_count.most_common(20)]
#print(labels)
#print(diff)
# Out:
# [0.16678924573016263, 0.12263354307973087, 0.09868976601018768, 0.07204924954373348, 0.059301026940154176, 0.05668600691890714, 0.055814333578491464, 0.04385606493966386, 0.041540682629184714, 0.03701887717577838, 0.030917163792868622, 0.029800332325461032, 0.029310016071477214, 0.02394377706954319, 0.02372585873443927, 0.02296314456157555, 0.0228269456021356, 0.020892920378088313, 0.02075672141864836, 0.02048432349976846]
# [-0.16947334548964926, -0.12581786978440415, -0.09782258929529121, -0.06972004719510887, -0.05835031642175265, -0.05717043869998927, -0.0553469913118095, -0.043440952483106296, -0.04011584253995495, -0.03925774965139976, -0.02971146626622332, -0.028746111766598734, -0.028209803711251744, -0.02402660087954521, -0.02402660087954521, -0.02327576960205942, -0.023168507990990024, -0.022632199935643034, -0.01984339804783868, -0.01984339804783868]

# %%
plt.style.use('fivethirtyeight')
fig, ax = plt.subplots(figsize=(10,6))
test_bar = ax.bar(np.arange(len(Y_test_freq)), Y_test_freq, 0.9, label="Test Set", linewidth=0, align='center')
train_bar = ax.bar(np.arange(len(Y_train_freq)), Y_train_freq, 0.9, label="Train Set", linewidth=0, align='center')
diff_line, = ax.plot(np.arange(len(Y_test_freq)), diff, 'y', linewidth=6, c='white')
ax.set_title("Répartition des 20 tags les moins représentés dans les 2 datasets", fontsize=25)
plt.xticks(np.arange(len(labels)), labels, fontsize=15, rotation=90)
for tick in ax.yaxis.get_major_ticks():
    tick.label.set_fontsize(15) 
ax.set_ylabel("Fréquence", fontsize=20)
ax.legend((train_bar[0],test_bar[0], diff_line),('Train Set','Test Set','Difference'), fontsize=15)
plt.show()

# %%
from collections import Counter
# Fréquence du nombre de tags par document
Y_train_count = Counter(x for y in mlb.inverse_transform(Y_train) for x in y)
Y_train_freq = [x[1]/sum(x[1] for x in Y_train_count.most_common()[:-101:-1]) for x in Y_train_count.most_common()[:-101:-1]]
#print(Y_train_freq)
Y_test_count = Counter(x for y in mlb.inverse_transform(Y_test) for x in y)
Y_test_freq = [-x[1]/sum(x[1] for x in Y_test_count.most_common()[:-101:-1]) for x in Y_test_count.most_common()[:-101:-1]]
#print(Y_test_freq)
diff = [x + y for x, y in zip(Y_train_freq, Y_test_freq)]
labels = [x[0] for x in Y_train_count.most_common()[:-101:-1]]
#print(labels)
#print(diff)
plt.style.use('fivethirtyeight')
fig, ax = plt.subplots(figsize=(20,8))
test_bar = ax.bar(np.arange(len(Y_test_freq)), Y_test_freq, 0.9, label="Test Set", linewidth=0, align='center')
train_bar = ax.bar(np.arange(len(Y_train_freq)), Y_train_freq, 0.9, label="Train Set", linewidth=0, align='center')
diff_line, = ax.plot(np.arange(len(Y_test_freq)), diff, 'y', linewidth=4, c='white')
ax.set_title("Répartition des tags dans les 2 datasets", fontsize=25)
plt.xticks(np.arange(len(labels)), labels, fontsize=15, rotation=90)
for label in ax.xaxis.get_ticklabels()[::2]:
    label.set_visible(False)
for tick in ax.yaxis.get_major_ticks():
    tick.label.set_fontsize(15) 
ax.set_ylabel("Fréquence", fontsize=20)
ax.legend((train_bar[0],test_bar[0], diff_line),('Train Set','Test Set','Difference'), fontsize=15)
plt.show()

# %%
def n_tags_by_labels(data, data_label):
    import matplotlib.pyplot as plt
    # Nombre de tags par document
    Y_n_tags = np.sum(data,axis=1)
    # Fréquence du nombre de tags par document
    import collections
    multiLabel_counts = collections.Counter(Y_n_tags)
    # clés 
    # print([x[0] for x in multiLabel_counts.most_common()])
    # valeurs 
    # print([x[1] for x in multiLabel_counts.most_common()])
    plt.figure(figsize=(15,5))
    ax = sns.barplot([x[0] for x in multiLabel_counts.most_common()], [x[1] for x in multiLabel_counts.most_common()])
    plt.title("Questions having multiple tags : {}".format(data_label), fontsize=20)
    plt.xticks(fontsize=15)
    plt.yticks(fontsize=15)    
    plt.ylabel('Number of questions', fontsize=18)
    plt.xlabel('Number of tags', fontsize=18)
    #adding the text labels
    rects = ax.patches
    labels = [x[1] for x in multiLabel_counts.most_common()] / np.sum([x[1] for x in multiLabel_counts.most_common()]) 
    labels = ["{:0.1%}".format(x) for x in labels]
    for rect, label in zip(rects, labels):
        height = rect.get_height()
        ax.text(rect.get_x() + rect.get_width()/2, height + 5, label, ha='center', va='bottom', fontsize=15)      
    plt.style.use('fivethirtyeight')        
    return

# %%
n_tags_by_labels(Y_train, 'Y_train_top100tags_3labels') 
n_tags_by_labels(Y_test, 'Y_test_top100tags_3labels')

# %%
from sklearn.dummy import DummyClassifier
from sklearn.metrics import jaccard_score
from sklearn.multiclass import OneVsRestClassifier

dummy_clf = OneVsRestClassifier(DummyClassifier(strategy="stratified"))
dummy_clf.fit(X_tfidf_train, Y_train)

Y_pred = dummy_clf.predict(X_tfidf_test)
print(jaccard_score(Y_test, Y_pred, average='weighted'))
# Out:
# 0.02707875023683843

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.naive_bayes import MultinomialNB
from sklearn.multiclass import OneVsRestClassifier

clf = OneVsRestClassifier(MultinomialNB())

parameters = {
    'estimator__alpha': [0.0001, 0.001, 0.01, 0.1, 1],
    'estimator__fit_prior' : [True, False]
}

mnb_topntags_3labels = GridSearchCV(clf, param_grid=parameters, scoring='jaccard_weighted', n_jobs=-1, verbose=3)
mnb_topntags_3labels.fit(X_tfidf_train, Y_train)

print (mnb_topntags_3labels.best_params_, mnb_topntags_3labels.best_score_)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:   13.3s
# [Parallel(n_jobs=-1)]: Done  50 out of  50 | elapsed:   27.9s finished
# {'estimator__alpha': 0.01, 'estimator__fit_prior': False} 0.16586899997723276

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.multiclass import OneVsRestClassifier

clf = OneVsRestClassifier(LogisticRegression(solver='liblinear', random_state=42))

parameters = {
    'estimator__penalty': ['l1', 'l2'], 
    'estimator__C': [0.1, 1, 10, 100, 1000]
}

lr_topntags_3labels = GridSearchCV(clf, param_grid=parameters, scoring='jaccard_weighted', n_jobs=-1, verbose=3)
lr_topntags_3labels.fit(X_tfidf_train, Y_train)

print (lr_topntags_3labels.best_params_, lr_topntags_3labels.best_score_)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=-1)]: Done  50 out of  50 | elapsed: 19.4min finished
# {'estimator__C': 10, 'estimator__penalty': 'l1'} 0.3317831459960757

# %%
# SAUVEGARDE
with open('lr_top100tags_3labels.pkl', 'wb') as f:
    pickle.dump(lr_topntags_3labels, f)

# %%
from sklearn.metrics import jaccard_score
import matplotlib.pyplot as plt

jaccard_list = []

for s in np.linspace(0, 1, 10, dtype='float'):

    Y_pred = pd.DataFrame(lr_topntags_3labels.best_estimator_.predict_proba(X_tfidf_test)).applymap(lambda x:1 if x>s else 0).to_numpy()
    jaccard_list.append(jaccard_score(Y_test, Y_pred, average='weighted'))
                                
plt.title("Evolution of jaccard score depending on threshold", fontsize=20)
plt.xlabel("Threshold")
plt.ylabel("Jaccard Score")
plt.plot(np.linspace(0, 1, 10, dtype='float'), jaccard_list)
plt.grid(True, linestyle=":")
plt.style.use('fivethirtyeight')
plt.show()

# %%
Y_pred = pd.DataFrame(lr_topntags_3labels.best_estimator_.predict_proba(X_tfidf_test)).applymap(lambda x:1 if x>0.22 else 0).to_numpy()
Y_true = pd.Series(mlb.inverse_transform(Y_test))
Y_pred = pd.Series(mlb.inverse_transform(Y_pred))
display(pd.concat([Y_true, Y_pred], axis=1)[:20])
# Out:
#                                     0  \
# 0   (ruby, ruby-on-rails)
# 1   (c#,)
# 2   (version-control,)
# 3   (.net, c++)
# 4   (javascript,)
# 5   (command-line, linux)
# 6   (vb.net,)
# 7   (.net, user-interface, vb.net)
# 8   (css, html, internet-explorer)
# 9   (c#, xml)
# 10  (.net, vb.net)
# 11  (java, unix, windows)
# 12  (design-patterns, java)
# 13  (bash, scripting, shell)
# 14  (objective-c,)
# 15  (.net, asp.net, database)
# 16  (http, performance, unit-testing)
# 17  (eclipse,)
# 18  (django, python)
# 19  (linux,)
#
#                                            1
# 0   (c#, optimization, performance)
# 1   ()
# 2   (.net,)
# 3   (c++,)
# 4   (asp.net, internet-explorer, javascript)
# 5   (shell,)
# 6   (.net, c#)
# 7   (.net, multithreading, winforms)
# 8   (java,)
# 9   (c#, xml)
# 10  (c#, python)
# 11  (file, unix)
# 12  (c++, design-patterns, java)
# 13  ()
# 14  (objective-c,)
# 15  (.net, c#)
# 16  (unit-testing,)
# 17  (eclipse, java)
# 18  (django,)
# 19  (linux,)

# %% [markdown]
# # Fonction de recommandation de tags
#
# Recommande des mots issus des analyses supervisées et non supervisées

# %%
from utils import clean_whitespace_and_code, apply_specialtags_transco, clean_punctuation, stopWordsRemove, lemmatization

# CHARGEMENT
with open('lda_model_list.pkl', 'rb') as f:
    lda_model_list = pickle.load(f)    
with open('lr_top100tags_3labels.pkl', 'rb') as f:
    lr_topntags_3labels = pickle.load(f) 
with open('mlb.pkl', 'rb') as f:
    mlb = pickle.load(f) 
with open('tfidf.pkl', 'rb') as f:
    tfidf = pickle.load(f)     

posts_body_clean = pd.read_pickle("./posts_body_clean.pkl")

# %%
def recommend_tags(text_ori, n_words, mlb, tfidf, lda, clf, seuil=0.5, clean=False):
    
    ''' 
    Recommendation system for StackOverflow posts based on a unsupervised model which returns 
    up to 5 words and and supervised model which returns up to 3 words.

    Parameters:

    text_ori: the stackoverflow post of user
    n_words: number of tags to recommend
    seuil: threshold for decision
    clean: True if data preparation is needed
    '''

    auto_stopwords = set(set(nlp.Defaults.stop_words) | set(stopwords.words("english")))
    with open('manual_stopwords.pkl', 'rb') as f:
        manual_stopwords = pickle.load(f) 
    with open('ignore_words.pkl', 'rb') as f:
        ignore_words = pickle.load(f) 
    with open('specialtags.pkl', 'rb') as f:
        specialtags = pickle.load(f)         
    
    if type(text_ori) in (str, pd.Series):
        if type(text_ori) is str:
            text_ori = pd.Series(text_ori) 
        text = text_ori
        text_ori = text_ori.rename("Texte d'origine")
        text = text.rename("Texte modifié")
    else:
        return 'Type should be str or pd.Series'

    if clean==True:
        text = text.apply(lambda s: clean_whitespace_and_code(s))
        text = text.apply(lambda s: BeautifulSoup(s).get_text())
        text = text.apply(lambda s: apply_specialtags_transco(s, specialtags))
        text = text.apply(lambda s: clean_punctuation(s))
        text = text.apply(lambda s: stopWordsRemove(s, auto_stopwords))
        text = text.apply(lambda s: lemmatization(s, ['NOUN'], ignore_words))   
        text = text.apply(lambda s: stopWordsRemove(s, manual_stopwords))

    # document = question StackOverflow
    # word = il s'agit des mots issus du vocabulaire LDA, retenus par le LDA (max_features)
    # topic = il s'agit des topics issus du LDA (components)
    # pour chaque document et chaque mot, je calcule la probabilité totale qu'un mot apparaisse dans le document 
    # proba(word1) = proba(word1/topic1) * proba(topic1) + proba(word1/topic2) * proba(topic2) ...
    # je conserve les n_tags
    
    document_tfidf = tfidf.transform(text)
    proba_topic_sachant_document = lda.transform(document_tfidf)
    inv_specialtags = {v: k for k, v in dict(specialtags).items()}
    words_label = []
    for word in tfidf.get_feature_names():
        if word in inv_specialtags.keys():
            words_label.append(inv_specialtags[word])
        else:
            words_label.append(word)
    proba_word_sachant_topic = lda.components_ / lda.components_.sum(axis=1)[:, np.newaxis] # normalization    
    #print(proba_topic_sachant_document.shape)    
    #print(proba_word_sachant_topic.shape)    
    
    # proba_topic_sachant_document est de dimension d x t
    # proba_word_sachant_topic est de dimension t x w
    # je peux donc opérer un produit matriciel entre les 2 matrices pour calculer pour chaque document : proba(wordn)
    # j'obtiendrai une matrice proba_word_sachant_document de dimension d x w
    # il ne me restera plus qu'à choisir les "n_words" mots les plus probables
    proba_word_sachant_document = proba_topic_sachant_document.dot(proba_word_sachant_topic)  
    
    # je transforme la matrice en dataframe : 
    # data = les proba des mots pour chaque document
    # index = l'index des données en entrée
    # columns = les labels des mots sélectionnés en sortie du LDA
    df_wd = pd.DataFrame(data=proba_word_sachant_document,
                         index=text.index,
                         columns=words_label) 
    
    # np.argsort(-df_wd.values, axis=1)[:, :n_words])
    # renvoie pour chaque document, les "n_words" indexes des colonnes dont les proba sont les plus élevées
    # grâce aux indexes, je peux récupérer le libellé de la colonne qui est donc le libellé du mot 
    # et le stocker en ligne
    values = df_wd.columns.values[np.argsort(-df_wd.values, axis=1)[:, :n_words]]
    values = [", ".join(item) for item in values.astype(str)]
    #pred_unsupervised = pd.DataFrame(df_wd.columns.values[np.argsort(-df_wd.values, axis=1)[:, :n_words]],
    #                                 index=df_wd.index,
    #                                 columns = ['word' + str(i + 1) for i in range(n_words)])
    pred_unsupervised = pd.DataFrame(values,
                                     index=df_wd.index,
                                     columns = ['Unsupervised'])
    
    pred_supervised = pd.DataFrame(clf.predict_proba(tfidf.transform(text))).applymap(lambda x:1 if x>seuil else 0).to_numpy()
    pred_supervised = pd.Series(mlb.inverse_transform(pred_supervised), name='Supervised', index=text.index)
    pred_supervised = pred_supervised.apply(lambda row: ', '.join(row))
    result = pd.concat([pred_supervised, pred_unsupervised, text_ori, text], axis=1)
    
    return result

# %%
test = "this sql request grouping values by keys on the relational database is not working."
display(recommend_tags(test, 5, mlb, tfidf, lda_model_list[4], lr_topntags_3labels.best_estimator_, seuil=0.22, clean=True))

test = "I want to develop a web application generating html, javascript and css, what is the good language to do that."
display(recommend_tags(test, 5, mlb, tfidf, lda_model_list[4], lr_topntags_3labels.best_estimator_, seuil=0.22, clean=True))

test = "I want to code a Python function to sum item from a dictionary."
display(recommend_tags(test, 5, mlb, tfidf, lda_model_list[4], lr_topntags_3labels.best_estimator_, seuil=0.22, clean=True))

test = posts_body_clean.loc[2:5]
display(recommend_tags(test, 5, mlb, tfidf, lda_model_list[4], lr_topntags_3labels.best_estimator_, seuil=0.22, clean=False))
#test = X_test[:2]
# Out:
#       Supervised                          Unsupervised  \
# 0  database, sql  table, sql, database, column, server
#
#                                                                        Texte d'origine  \
# 0  this sql request grouping values by keys on the relational database is not working.
#
#               Texte modifié
# 0  sql request key database
#                        Supervised                     Unsupervised  \
# 0  asp.net, css, html, javascript  xml, css, javascript, php, html
#
#                                                                                                   Texte d'origine  \
# 0  I want to develop a web application generating html, javascript and css, what is the good language to do that.
#
#                          Texte modifié
# 0  web application html javascript css
#   Supervised                            Unsupervised  \
# 0  python     python, application, event, code, .net
#
#                                                    Texte d'origine  \
# 0  I want to code a Python function to sum item from a dictionary.
#
#   Texte modifié
# 0  python item
#       Supervised                                     Unsupervised  \
# 2                 property, class, object, window, interface
# 3  datetime       test, unit, date, testing, time
# 4  asp.net, http  flash, linux, silverlight, application, windows
# 5  .net, c#       python, eclipse, application, .net, project
#
#                                         Texte d'origine  \
# 2  person birthday calculate age
# 3  display time hour day month
# 4  web server determine timezone web http header string
# 5  xyzspecialtags1zyx
#
#                                           Texte modifié
# 2  person birthday calculate age
# 3  display time hour day month
# 4  web server determine timezone web http header string
# 5  xyzspecialtags1zyx

# %%
test = posts_body_clean.loc[2:5]
test
# Out:
# 2    person birthday calculate age
# 3    display time hour day month
# 4    web server determine timezone web http header string
# 5    xyzspecialtags1zyx
# Name: Body, dtype: object
